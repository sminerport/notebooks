# %%
import tensorflow as tf
import numpy as np

# %%
mat_1 = [[10,20,30],
         [40,50,60]]

# %%
mat_2 = tf.constant([[10,20,30],[40,50,60]])

# %%
mat_3 = np.array([[10,20,30],[40,50,60]])

# %%
print(mat_1)
# Out:
# [[10, 20, 30], [40, 50, 60]]

# %%
print(mat_2)
# Out:
# tf.Tensor(
# [[10 20 30]
#  [40 50 60]], shape=(2, 3), dtype=int32)

# %%
print(mat_3)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
h=tf.constant("Hello ")
t=tf.constant("Tensorflow!")
ht = h+t
print(ht)
# Out:
# tf.Tensor(b'Hello Tensorflow!', shape=(), dtype=string)

# %% [markdown]
# # import tensorflow as tf

# %% [markdown]
# ## Without session in tensorflow

# %%
a=tf.constant([1,2,3])
print(a)
# Out:
# tf.Tensor([1 2 3], shape=(3,), dtype=int32)

# %%
s=tf.compat.v1.Session()
print(s.run(a))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\Users\Scott\OneDrive\dev\notebooks\tensorflow-intro.ipynb Cell 12' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Scott/OneDrive/dev/notebooks/tensorflow-intro.ipynb#ch0000011?line=0'>1</a> s=tf.compat.v1.Session()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Scott/OneDrive/dev/notebooks/tensorflow-intro.ipynb#ch0000011?line=1'>2</a> print(s.run(a))
#
# File c:\Users\Scott\OneDrive\Documents\VisualStudio\chatbot-final\venv\lib\site-packages\tensorflow\python\client\session.py:967, in BaseSession.run(self, fetches, feed_dict, options, run_metadata)
#     <a href='file:///c%3A/Users/Scott/OneDrive/Documents/VisualStudio/chatbot-final/venv/lib/site-packages/tensorflow/python/client/session.py?line=963'>964</a> run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
# ...
